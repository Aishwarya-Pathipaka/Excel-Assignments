# %% [markdown]
# ## 1.Convert to Date Format (Convert-to-Date-Format.xlsx)
# This time, you have been given a file containing Text dates into various formats. The challenge before you is to write a single formula to convert them into an appropriate date format.

# %% [markdown]
# ## Ans:

# %% [markdown]
# For this we have to use =DATE(Year,Month,Date),which takes Year,Month,Date and gives the correct format

# %% [markdown]
# ![Screenshot%202022-04-21%20104315.jpg](attachment:Screenshot%202022-04-21%20104315.jpg)

# %% [markdown]
# In the above screenshot we can see the formula that is used for formatting.After applying to that one cell,we can drag the cursor from that cell to down.It will be applied to alla the cells.
