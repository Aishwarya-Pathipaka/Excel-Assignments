# %% [markdown]
# ## Find duplicates and show the count.

# %% [markdown]
# use the formula shown below in any cell here i used E2 cell then drag down
# =LEFT(SUBSTITUTE(IF(ISNUMBER(FIND("(",A2)),SUBSTITUTE(A2,"("," "),SUBSTITUTE(A2&"-","-","%"))," ","%",2),FIND("%",SUBSTITUTE(IF(ISNUMBER(FIND("(",A2)),SUBSTITUTE(A2,"("," "),SUBSTITUTE(A2&"-","-","%"))," ","%",2))-1)

# %% [markdown]
# ![asgnmnt%203.jpg](attachment:asgnmnt%203.jpg)
